# %%
# 1. Download your actual Huggingface repo from GitHub
# !git clone https://github.com

# 2. Move directly into the correct folder
# %cd Huggingface

# 3. Install systemic Linux packages (poppler-utils for visual PDFs)
# !apt-get update && apt-get install -y $(cat packages.txt)

# 4. Force compilation with NVIDIA CUDA acceleration enabled for your T4 GPU
# !CMAKE_ARGS="-DLLAMA_CUDA=on" pip install -q -r requirements.txt
# !npm install -g localtunnel

# 5. Generate Tunnel Password 
print("\n👉 COPY THIS IP ADDRESS (Your Tunnel Password):")
# !curl ifconfig.me
print("\n")

# 6. Boot Streamlit in the background
# !streamlit run app.py &/content/logs.txt &

# 7. Expose the server to a public link
# !npx localtunnel --port 8501
